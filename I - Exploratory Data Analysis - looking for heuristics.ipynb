# %%
import pandas as pd
import seaborn as sns
import math
sns.set()
credit = pd.read_csv('credit.csv')
credit_binary = credit.replace({'class':{'good':0, 'bad':1}})
import matplotlib.pyplot as plt

# %%
credit.head()
# Out:
#   checking_status  duration                    credit_history  \
# 0            '<0'         6  'critical/other existing credit'
# 1      '0<=X<200'        48                   'existing paid'
# 2   'no checking'        12  'critical/other existing credit'
# 3            '<0'        42                   'existing paid'
# 4            '<0'        24              'delayed previously'
#
#                    purpose  credit_amount      savings_status employment  \
# 0             buy_radio_tv           1169  'no known savings'      '>=7'
# 1             buy_radio_tv           5951              '<100'   '1<=X<4'
# 2                education           2096              '<100'   '4<=X<7'
# 3  buy_furniture_equipment           7882              '<100'   '4<=X<7'
# 4              buy_new_car           4870              '<100'   '1<=X<4'
#
#    installment_commitment       personal_status other_parties  ...  \
# 0                       4         'male single'          none  ...
# ...

# %%
sns.histplot(data=credit, x="age", hue="class", element="poly")
plt.plot()
# Out:
# []

# %%
sns.histplot(data=credit, x="existing_credits", hue="class", element="poly")
plt.plot()
# Out:
# []

# %%
sns.histplot(data=credit, x="checking_status", hue="class", element="bars")
plt.plot()
# Out:
# []

# %% [raw]
# Heuristic found:
# If a client has no checking, very likely to pay back loan

# %%
sns.histplot(data=credit, x="savings_status", hue="class", element="bars")
plt.plot()
# Out:
# []

# %%
sns.histplot(data=credit, x="credit_history", hue="class", element="bars")
plt.plot()
# Out:
# []

# %%
credit_binary.groupby(['credit_history', 'savings_status']).agg({
    'class':['mean', 'count']
})
# Out:
#                                                         class
#                                                          mean count
# credit_history                   savings_status
# 'all paid'                       '100<=X<500'        0.625000     8
#                                  '500<=X<1000'       0.200000     5
#                                  '<100'              0.720000    25
#                                  '>=1000'            0.333333     3
#                                  'no known savings'  0.375000     8
# 'critical/other existing credit' '100<=X<500'        0.150000    20
#                                  '500<=X<1000'       0.235294    17
#                                  '<100'              0.211111   180
#                                  '>=1000'            0.050000    20
#                                  'no known savings'  0.071429    56
# 'delayed previously'             '100<=X<500'        0.142857    14
# ...

# %% [raw]
# Heuristics found:
#
# 23% of 99 clients who are 'existing paid' and 'no known savings' defaulted
# 21% of 180 clients who are 'critical/other existing credit' and '<100' defaulted

# %%
sns.scatterplot(data=credit, x="credit_history", y="credit_amount", hue="class", style="class")
plt.plot()
# Out:
# []

# %%
credit.credit_history
# Out:
# 0      'critical/other existing credit'
# 1                       'existing paid'
# 2      'critical/other existing credit'
# 3                       'existing paid'
# 4                  'delayed previously'
#                      ...
# 995                     'existing paid'
# 996                     'existing paid'
# 997                     'existing paid'
# 998                     'existing paid'
# 999    'critical/other existing credit'
# Name: credit_history, Length: 1000, dtype: object

# %%
sns.histplot(data=credit[credit['credit_history']=="\'existing paid\'"]
             , x="credit_amount", hue="class", element="bars")
plt.plot()
# Out:
# []
